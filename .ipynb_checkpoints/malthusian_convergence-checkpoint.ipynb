# %% [markdown]
# ## <font color="880000"> Malthusian Model: Convergence </font>
#
# Recall:
#
# >(1) $ \frac{dL/dt}{L} = \frac{d\ln(L)}{dt} = n = \beta  \left( \frac{y}{\phi y^{sub}}-1 \right) $
#
# >(2) $ \ln(y) = \theta\ln(\kappa) + \ln(H) -\ln(L)/\gamma $
#
# Substitute:
#
# >(3) $ \frac{1}{L}\frac{dL}{dt} = \frac{d\ln(L)}{dt} = n = \beta  \left( \frac{\kappa^\theta H L^{-\gamma}}{\phi y^{sub}}-1 \right) $
#
# >(4) $ \frac{d\kappa}{dt} = -(1-\alpha)(h + (1-1/\gamma)n +\delta)\kappa + (1-\alpha)s $
#
# Define population-adjusted-for-ideas $ P $:
#
# >(5) $ P = L H^{-\gamma} $
#
# Then we have two state variables—capital-intensity $ \kappa $, the capital-output ratio, and population-adjusted-for-ideas $ P $. We have two dynamic equations: The rate of change of population-adjusted-for-ideas $ P $ is a function of the capital-output ratio and itself:
#
# >(6) $ \frac{1}{P}\frac{dP}{dt} = p = \beta  \left( \frac{\kappa^\theta }{P^{1/\gamma} \phi y^{sub}}-1 \right) -h\gamma $
#
# And the rate of change of capital-intensity $ \kappa $ is a function of itself andf of the rate of change of population-adjusted-for-ideas $ P $:
#
# >(7) $ \frac{d\kappa}{dt} = (1-\alpha)s -(1-\alpha)((1-1/\gamma)p + \gamma h +\delta)\kappa  $
#
# With the two parameters $ \alpha $ and $ \theta $ related by:
#
# >(8) $ \theta = \frac{\alpha}{1-\alpha}  $
#
# >(9) $ \alpha = \frac{\theta}{1+\theta}   $
#
# And if we set:
#
# >(10) $ P = \Pi P^{*mal}     $
#
# >(11) $ \frac{1}{\Pi}\frac{d\Pi}{dt} = p = \beta \left[ \Pi^{(-1/\gamma)} \kappa^\theta (s/(\delta + \gamma h))^{-\theta} (1 + \gamma h/\beta) -1 \right] - h \gamma $
#
# (7) and (11) are then our system...
#
# &nbsp;
#
# Define:
#
# >(12) $ \kappa = k \kappa^{*mal} = k (s/(\delta + \gamma h)) $
#
# Then (7) becomes:
#
# >(13) $ \kappa^{*mal} \frac{dk}{dt} =  \left[ (1-\alpha)s -(1-\alpha)((1-1/\gamma)p + \gamma h +\delta) k (s/(\delta + \gamma h)) \right]  $
#
# And (11) becomes:
#
# >(14) $ \frac{1}{\Pi}\frac{d\Pi}{dt} = p = \beta \left[ \Pi^{(-1/\gamma)} k^\theta  (1 + \gamma h/\beta) -1 \right] - h \gamma $
#
# Linearize around $ \Pi = k = 1 $, $ p = 0 $:
#
# >(15) $ \frac{dk}{dt} = -(1-\alpha)(1-1/\gamma)p -(1-\alpha)(\delta + \gamma h)(k - 1)  $
#
# >(16) $ \frac{d\Pi}{dt} = p = - h (\Pi - 1) + \theta (\beta + \gamma h)(k - 1) $
#
# >(17) $ \frac{dk}{dt} = (1-\alpha)(1-1/\gamma)h (\Pi - 1) -(1-\alpha)\left[ (1-1/\gamma)\theta (\beta + \gamma h) + (\delta + \gamma h) \right](k - 1)  $
#
# ----

# %% [markdown]
# ## <font color="880000"> Malthusian: Convergence </font>
#
# <img src="https://tinyurl.com/20190119a-delong" width="300" style="float:right" />
#
# ### <font color="000088">Catch Our Breath—Further Notes:</font>
#
#
#
# ----
#
#
#
#
#
# <br clear="all" />
#
# ----
#
# * Weblog Support <>
# * nbViewer <>
#
# &nbsp;
